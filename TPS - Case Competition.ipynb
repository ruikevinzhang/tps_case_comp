# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
ksi_df = pd.read_csv("KSI.csv")

# %%
ksi_df.columns
# Out:
# Index(['X', 'Y', 'Index_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'HOUR', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'District', 'WardNum', 'Division',
#        'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE',
#        'INJURY', 'FATAL_NO', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT',
#        'DRIVCOND', 'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT',
#        'CYCCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV',
#        'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'Hood_ID', 'Neighbourhood',
#        'ObjectId'],
#       dtype='object')

# %%
ksi_df.isna().sum()
# Out:
# X                    0
# Y                    0
# Index_               0
# ACCNUM               0
# YEAR                 0
# DATE                 0
# TIME                 0
# HOUR                 0
# STREET1              0
# STREET2           1395
# OFFSET           13705
# ROAD_CLASS         368
# District            13
# WardNum           2298
# Division             0
# LATITUDE             0
# LONGITUDE            0
# LOCCOORD           130
# ACCLOC            5450
# TRAFFCTL            29
# VISIBILITY          22
# LIGHT                0
# RDSFCOND            27
# ACCLASS              0
# IMPACTYPE            4
# INVTYPE             10
# INVAGE               0
# INJURY            1609
# FATAL_NO         15420
# INITDIR           4836
# VEHTYPE           2527
# MANOEUVER         6952
# DRIVACT           8061
# DRIVCOND          8061
# PEDTYPE          13523
# PEDACT           13529
# PEDCOND          13409
# CYCLISTYPE       15452
# CYCACT           15427
# CYCCOND          15428
# ...

# %%
ksi_df.PEDESTRIAN.loc[~ksi_df.PEDESTRIAN.isnull()] = 1  # not nan
ksi_df.PEDESTRIAN.loc[ksi_df.PEDESTRIAN.isnull()] = 0   # nan

ksi_df.CYCLIST.loc[~ksi_df.CYCLIST.isnull()] = 1  # not nan
ksi_df.CYCLIST.loc[ksi_df.CYCLIST.isnull()] = 0   # nan

ksi_df.AUTOMOBILE.loc[~ksi_df.AUTOMOBILE.isnull()] = 1  # not nan
ksi_df.AUTOMOBILE.loc[ksi_df.AUTOMOBILE.isnull()] = 0   # nan

ksi_df.MOTORCYCLE.loc[~ksi_df.MOTORCYCLE.isnull()] = 1  # not nan
ksi_df.MOTORCYCLE.loc[ksi_df.MOTORCYCLE.isnull()] = 0   # nan

ksi_df.TRUCK.loc[~ksi_df.TRUCK.isnull()] = 1  # not nan
ksi_df.TRUCK.loc[ksi_df.TRUCK.isnull()] = 0   # nan

ksi_df.TRSN_CITY_VEH.loc[~ksi_df.TRSN_CITY_VEH.isnull()] = 1  # not nan
ksi_df.TRSN_CITY_VEH.loc[ksi_df.TRSN_CITY_VEH.isnull()] = 0   # nan

ksi_df.EMERG_VEH.loc[~ksi_df.EMERG_VEH.isnull()] = 1  # not nan
ksi_df.EMERG_VEH.loc[ksi_df.EMERG_VEH.isnull()] = 0   # nan

ksi_df.PASSENGER.loc[~ksi_df.PASSENGER.isnull()] = 1  # not nan
ksi_df.PASSENGER.loc[ksi_df.PASSENGER.isnull()] = 0   # nan

ksi_df.SPEEDING.loc[~ksi_df.SPEEDING.isnull()] = 1  # not nan
ksi_df.SPEEDING.loc[ksi_df.SPEEDING.isnull()] = 0   # nan

ksi_df.AG_DRIV.loc[~ksi_df.AG_DRIV.isnull()] = 1  # not nan
ksi_df.AG_DRIV.loc[ksi_df.AG_DRIV.isnull()] = 0   # nan

ksi_df.REDLIGHT.loc[~ksi_df.REDLIGHT.isnull()] = 1  # not nan
ksi_df.REDLIGHT.loc[ksi_df.REDLIGHT.isnull()] = 0   # nan

ksi_df.ALCOHOL.loc[~ksi_df.ALCOHOL.isnull()] = 1  # not nan
ksi_df.ALCOHOL.loc[ksi_df.ALCOHOL.isnull()] = 0   # nan

ksi_df.DISABILITY.loc[~ksi_df.DISABILITY.isnull()] = 1  # not nan
ksi_df.DISABILITY.loc[ksi_df.DISABILITY.isnull()] = 0   # nan

ksi_df.INJURY.loc[ksi_df.INJURY.isnull()] = 'None'   # nan
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ksi_df
# Out:
#                  X            Y    Index_      ACCNUM  YEAR  \
# 0     -8829728.092  5419070.899   3389067      893184  2006
# 1     -8829728.092  5419070.899   3389068      893184  2006
# 2     -8829728.092  5419070.899   3389069      893184  2006
# 3     -8829728.092  5419070.899   3389070      893184  2006
# 4     -8829728.092  5419070.899   3389071      893184  2006
# ...            ...          ...       ...         ...   ...
# 16088 -8851734.397  5427216.682  81356467  9002496688  2019
# 16089 -8851734.397  5427216.682  81356468  9002496688  2019
# 16090 -8837083.082  5412746.086  81340413  9002500260  2019
# 16091 -8837083.082  5412746.086  81340414  9002500260  2019
# 16092 -8837083.082  5412746.086  81340415  9002500260  2019
#
#                          DATE  TIME  HOUR       STREET1      STREET2  ...  \
# 0      2006/01/01 05:00:00+00   236     2  WOODBINE AVE  O CONNOR DR  ...
# 1      2006/01/01 05:00:00+00   236     2  WOODBINE AVE  O CONNOR DR  ...
# ...

# %%
# pd.Series(np.where(ksi_df.PEDESTRIAN.values == 'yes', 1, 0),
#           ksi_df.index)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Compute the correlation matrix
corr = ksi_df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
di = {'None': 0, 'Minimal': 0, 'Minor': 1,  'Major': 2, 'Fatal': 3,}

ksi_df['INJURY'] = ksi_df['INJURY'].map(di)

# %%
ksi_df['INJURY']
# Out:
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 16088    0
# 16089    2
# 16090    0
# 16091    0
# 16092    2
# Name: INJURY, Length: 16093, dtype: int64

# %%
groupksi_df = ksi_df.groupby(['ACCNUM']).max()

# %%
groupksi_df.columns
# Out:
# Index(['X', 'Y', 'Index_', 'YEAR', 'DATE', 'TIME', 'HOUR', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'District', 'WardNum', 'Division',
#        'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVAGE', 'INJURY',
#        'FATAL_NO', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE',
#        'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING',
#        'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'Hood_ID',
#        'Neighbourhood', 'ObjectId'],
#       dtype='object')

# %%
# groupksi_df.drop(columns = ['Hood_ID','ObjectId','YEAR','TIME','WardNum',
#                  'Division'])

# %%
groupksi_df.columns
# Out:
# Index(['X', 'Y', 'Index_', 'YEAR', 'DATE', 'TIME', 'HOUR', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'District', 'WardNum', 'Division',
#        'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVAGE', 'INJURY',
#        'FATAL_NO', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE',
#        'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING',
#        'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'Hood_ID',
#        'Neighbourhood', 'ObjectId'],
#       dtype='object')

# %%
groupksi_df.to_csv('tps_grouped_ksi.csv')

# %%
groupksi_df['INJURY']
# Out:
# ACCNUM
# 128407        2
# 882024        3
# 882079        2
# 882174        3
# 882497        3
#              ..
# 9002471073    2
# 9002481518    2
# 9002496688    2
# 9002500260    2
# 9085345312    2
# Name: INJURY, Length: 5690, dtype: int64
